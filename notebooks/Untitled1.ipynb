# %%
import nibabel as nib
from neuron.plot import slices
# Out:
# Using TensorFlow backend.

# %%
img = nib.load("/data/ddmg/voxelmorph/data/3dflair/ADNI/002_S_1261/Sagittal_3D_FLAIR/2017-03-15_11_23_54.0/S547087/ADNI_002_S_1261_MR_Sagittal_3D_FLAIR__br_raw_20170320133744912_149_S547087_I831073.nii").get_data() # this gives you a LxWxH volume

# %%
img2 = nib.load("/data/ddmg/voxelmorph/data/3dflair/ADNI/002_S_1261/Sagittal_3D_FLAIR/2017-03-15_11_23_54.0/S547087/ADNI_002_S_1261_MR_Sagittal_3D_FLAIR__br_raw_20170320133744912_149_S547087_I831073_robex.nii").get_data() # this gives you a LxWxH volume

# %%
print(img.shape)
slices([img2[80, :, :]])
# Out:
# (160, 256, 256, 1)
# (<matplotlib.figure.Figure at 0x7f082502ae48>,
#  [<matplotlib.axes._subplots.AxesSubplot at 0x7f085ab76320>])
